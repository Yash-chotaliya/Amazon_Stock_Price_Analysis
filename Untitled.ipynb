# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./dataset/data.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6516 entries, 0 to 6515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6516 non-null   object
#  1   Open       6516 non-null   float64
#  2   High       6516 non-null   float64
#  3   Low        6516 non-null   float64
#  4   Close      6516 non-null   float64
#  5   Adj Close  6516 non-null   float64
#  6   Volume     6516 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 356.5+ KB

# %%
df['Day'] = df['Date'].apply(lambda x:x.split('-')[2])
df['Month'] = df['Date'].apply(lambda x:x.split('-')[1])
df['Year'] = df['Date'].apply(lambda x:x.split('-')[0])

# %%
df['Day'] = df['Day'].astype(int)
df['Month'] = df['Month'].astype(int)
df['Year'] = df['Year'].astype(int)

df = df[df['Year']>1997]
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 160   1998-01-02    0.250000    0.250000    0.239844    0.247917    0.247917
# 161   1998-01-05    0.244271    0.246875    0.235417    0.237500    0.237500
# 162   1998-01-06    0.234896    0.243750    0.233333    0.241927    0.241927
# 163   1998-01-07    0.241667    0.241667    0.234635    0.239063    0.239063
# 164   1998-01-08    0.234896    0.235156    0.226563    0.230729    0.230729
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#          Volume  Day  Month  Year
# ...

# %%
grp = df.groupby(['Year','Month'])

# %%
# create new data frame which contains average open stock price for year 1998-2022

dict = {'Year':10,
        'Month':10,
        'Mean':10
       }
  
df1 = pd.DataFrame(dict,index=[0])
for i in range(2023-1998):
    for j in range(12):
        mean = grp.get_group((i+1998,j+1))['Open'].mean()
        df1.loc[len(df1.index)] = [int(i+1998),int(j+1),mean]

# %%
df1.drop(0,axis=0,inplace=True)

# %%
df1['Year'] = df1['Year'].astype(int)
df1['Month'] = df1['Month'].astype(int)
df1
# Out:
#      Year  Month        Mean
# 1    1998      1    0.240534
# 2    1998      2    0.261075
# 3    1998      3    0.335180
# 4    1998      4    0.383966
# 5    1998      5    0.375104
# ..    ...    ...         ...
# 296  2022      8  137.867828
# 297  2022      9  123.163810
# 298  2022     10  114.124762
# 299  2022     11   94.881428
# 300  2022     12   88.483334
#
# [300 rows x 3 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df1,x='Year',y='Mean',hue='Month')
# Out:
# <Axes: xlabel='Year', ylabel='Mean'>

# %%
df1.to_csv('./dataset/year_wise_stock.csv',index=False)
